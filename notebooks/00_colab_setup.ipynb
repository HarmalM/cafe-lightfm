# %% [markdown]
# # CAFE-LightFM — Colab Session Setup
#
# Run this notebook **first, every session**. It performs, in order:
#
# 1. Mount Google Drive (persistent storage for data/checkpoints/logs)
# 2. Clone or pull the GitHub repository (ephemeral code on the VM)
# 3. Install pinned dependencies from `requirements.txt`
# 4. Run `smoke_test.py` to validate the environment
# 5. Confirm GPU runtime is attached
#
# **Before running:** Runtime > Change runtime type > T4 GPU (or A100).

# %% [markdown]
# ## 1. Mount Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')

import os
DRIVE_ROOT = '/content/drive/MyDrive/cafe_lightfm'
os.makedirs(DRIVE_ROOT, exist_ok=True)
print(f'Persistent storage root: {DRIVE_ROOT}')

# %% [markdown]
# ## 2. Clone or Pull Repository
#
# **Replace `YOUR_GITHUB_USERNAME/cafe-lightfm` with your actual repo path.**
# If the repo is private, you will be prompted for a GitHub Personal Access Token
# (create one at https://github.com/settings/tokens with `repo` scope).

# %%
REPO_URL = 'https://github.com/YOUR_GITHUB_USERNAME/cafe-lightfm.git'  # EDIT ME
REPO_DIR = '/content/cafe-lightfm'

import os
if os.path.isdir(REPO_DIR):
    print('Repo exists — pulling latest changes...')
    # %cd {REPO_DIR}
    # !git pull
else:
    print('Cloning repo...')
    # !git clone {REPO_URL} {REPO_DIR}
    # %cd {REPO_DIR}

import sys
sys.path.insert(0, REPO_DIR)
print(f'Working directory: {os.getcwd()}')

# %% [markdown]
# ## 3. Install Dependencies

# %%
# Colab pre-installs torch with CUDA support — do NOT reinstall torch by
# default, as it can break the GPU build. Install everything else, then
# verify the existing torch build is CUDA-enabled.
# !pip install -q lightfm==1.17 pyyaml==6.0.1 joblib==1.4.2

import torch
print(f'torch version: {torch.__version__}')
print(f'CUDA available: {torch.cuda.is_available()}')
if torch.cuda.is_available():
    print(f'GPU: {torch.cuda.get_device_name(0)}')
else:
    print('WARNING: No GPU detected. Runtime > Change runtime type > GPU.')

# %% [markdown]
# ## 4. Set Drive Root Override and Run Smoke Test

# %%
import os
os.environ['CAFE_LIGHTFM_DRIVE_ROOT'] = DRIVE_ROOT

# !python smoke_test.py

# %% [markdown]
# ## 5. Session Ready
#
# If all checks above passed, the environment is configured:
# - Code: `/content/cafe-lightfm` (ephemeral, from GitHub)
# - Data / checkpoints / logs: `/content/drive/MyDrive/cafe_lightfm` (persistent)
#
# Proceed to the data pipeline or training notebooks.
